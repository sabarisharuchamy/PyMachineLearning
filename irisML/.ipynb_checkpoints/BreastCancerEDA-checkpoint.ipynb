# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
survival_df = pd.read_csv('haberman.csv', header = 0, 
                          names = ['patient_age', 'operation_year', 
                                   'positive_axillary_nodes', 
                                   'survival_status'])

# %%
survival_df.head()
# Out:
#    patient_age  operation_year  positive_axillary_nodes  survival_status
# 0           30              62                        3                1
# 1           30              65                        0                1
# 2           31              59                        2                1
# 3           31              65                        4                1
# 4           33              58                       10                1

# %%
survival_df.shape
# Out:
# (305, 4)

# %%
survival_df['survival_status'].value_counts()
# Out:
# 1    224
# 2     81
# Name: survival_status, dtype: int64

# %%
survival_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   patient_age              305 non-null    int64
#  1   operation_year           305 non-null    int64
#  2   positive_axillary_nodes  305 non-null    int64
#  3   survival_status          305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %%
survival_df['survival_status'] =survival_df['survival_status'].map({1:"yes", 2:"no"})

# %%
survival_df.head()
# Out:
#    patient_age  operation_year  positive_axillary_nodes survival_status
# 0           30              62                        3             yes
# 1           30              65                        0             yes
# 2           31              59                        2             yes
# 3           31              65                        4             yes
# 4           33              58                       10             yes

# %%
survival_df.describe()
# Out:
#        patient_age  operation_year  positive_axillary_nodes
# count   305.000000      305.000000               305.000000
# mean     52.531148       62.849180                 4.036066
# std      10.744024        3.254078                 7.199370
# min      30.000000       58.000000                 0.000000
# 25%      44.000000       60.000000                 0.000000
# 50%      52.000000       63.000000                 1.000000
# 75%      61.000000       66.000000                 4.000000
# max      83.000000       69.000000                52.000000

# %%
survival_df.describe(include=[object])
# Out:
#        survival_status
# count              305
# unique               2
# top                yes
# freq               224

# %%
survival_yes = survival_df[survival_df['survival_status'] == 'yes']
survival_yes.describe()
# Out:
#        patient_age  operation_year  positive_axillary_nodes
# count   224.000000      224.000000               224.000000
# mean     52.116071       62.857143                 2.799107
# std      10.937446        3.229231                 5.882237
# min      30.000000       58.000000                 0.000000
# 25%      43.000000       60.000000                 0.000000
# 50%      52.000000       63.000000                 0.000000
# 75%      60.000000       66.000000                 3.000000
# max      77.000000       69.000000                46.000000

# %%
survival_no = survival_df[survival_df['survival_status'] == 'no']
survival_no.describe()
# Out:
#        patient_age  operation_year  positive_axillary_nodes
# count    81.000000       81.000000                81.000000
# mean     53.679012       62.827160                 7.456790
# std      10.167137        3.342118                 9.185654
# min      34.000000       58.000000                 0.000000
# 25%      46.000000       59.000000                 1.000000
# 50%      53.000000       63.000000                 4.000000
# 75%      61.000000       65.000000                11.000000
# max      83.000000       69.000000                52.000000

# %%
survival_df.plot(kind = 'scatter', 
                 x = 'positive_axillary_nodes', 
                 y = 'patient_age') 
plt.grid()
plt.show()

# %%
sns.set(style = 'whitegrid')
sns.FacetGrid(survival_df, hue = 'survival_status', height = 6).map(plt.scatter, 'positive_axillary_nodes', 'patient_age').add_legend()
plt.show()

# %%
sns.set(style = 'whitegrid')
sns.pairplot(survival_df, hue = 'survival_status')
plt.show()

# %%
sns.jointplot(survival_df['patient_age'], 
              survival_df['positive_axillary_nodes'], 
              color = 'g').annotate(stats.pearsonr)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-3a1728a4be15> in <module>
# ----> 1 sns.jointplot(survival_df['patient_age'],
#       2               survival_df['positive_axillary_nodes'],
#       3               color = 'g').annotate(stats.pearsonr)
#       4 plt.show()
#
# AttributeError: 'JointGrid' object has no attribute 'annotate'

# %%
sns.FacetGrid(survival_df, hue="survival_status", height=5) \
   .map(sns.distplot, "patient_age") \
   .add_legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(survival_df, hue='survival_status', height=5) \
 .map(sns.distplot, 'operation_year') \
 .add_legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.FacetGrid(survival_df, hue='survival_status', height=5) \
 .map(sns.distplot, 'positive_axillary_nodes') \
 .add_legend()
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
survival_yes = survival_df[survival_df['survival_status'] == 'yes']
survival_no = survival_df[survival_df['survival_status'] == 'no']

# %%
counts, bin_edges = np.histogram(survival_yes['positive_axillary_nodes'],
 bins = 10, density = True)
pdf = counts/sum(counts)
cdf = np.cumsum(pdf)
print(bin_edges)
plt.plot(bin_edges[1:], pdf, label = 'PDF Survival status = Yes')
plt.plot(bin_edges[1:], cdf, label = 'CDF Survival status = Yes')
print('*'*75)
counts, bin_edges = np.histogram(survival_no['positive_axillary_nodes'],
bins = 10, density = True)
pdf = counts/sum(counts)
cdf = np.cumsum(pdf)
print(cdf)
print(bin_edges)
plt.plot(bin_edges[1:], pdf, label = 'PDF Survival status = No')
plt.plot(bin_edges[1:], cdf, label = 'CDF Survival status = No')
plt.legend()
plt.show()
# Out:
# [ 0.   4.6  9.2 13.8 18.4 23.  27.6 32.2 36.8 41.4 46. ]
# ***************************************************************************
# [0.56790123 0.71604938 0.85185185 0.90123457 0.97530864 0.97530864
#  0.98765432 0.98765432 0.98765432 1.        ]
# [ 0.   5.2 10.4 15.6 20.8 26.  31.2 36.4 41.6 46.8 52. ]

# %%
sns.set(style="ticks")
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.boxplot(x = 'survival_status', y = 'patient_age', data = survival_df)
plt.subplot(1,3,2)
sns.boxplot(x = 'survival_status', y = 'operation_year', data = survival_df)
plt.subplot(1,3,3)
sns.boxplot(x = 'survival_status', y = 'positive_axillary_nodes', data = survival_df)
plt.show()

# %%
plt.figure(figsize=(20,5))
plt.subplot(1,3,1)
sns.violinplot(x = 'survival_status', y = 'patient_age', data = survival_df)
plt.subplot(1,3,2)
sns.violinplot(x = 'survival_status', y = 'operation_year', data = survival_df)
plt.subplot(1,3,3)
sns.violinplot(x = 'survival_status', y = 'positive_axillary_nodes', data = survival_df)
plt.show()

# %%
sns.jointplot(x ='patient_age', y ='operation_year' , data = survival_df, kind = 'kde')
plt.show()
